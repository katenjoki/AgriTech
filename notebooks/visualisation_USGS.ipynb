# %%
import json
import pandas as pd
import urllib
from urllib.request import urlopen
import shapely
from shapely.geometry import Polygon
import geopandas
import laspy
import rasterio
from rasterio.plot import show
from rasterio import mask
import folium
import fiona

# %%
DATASET_PATH = "https://s3-us-west-2.amazonaws.com/usgs-lidar-public/"
JSON_PATH = "../data/data_usgs.json"
        
def get_data(dataset_path:str,json_path:str):
    geo_dict = {'Region':[],
                'File_path':[],
                'Bounds':[],
                'WKT':[]
                }
    with open('../filename.txt') as filenames:
        for f in filenames:
            f = f.strip('\n')
            geo_dict['Region'].append(f)
            file = dataset_path + f +"ept.json"
            geo_dict['File_path'].append(file)
            try:
                meta = json.load(urlopen(file))
                wkt = meta["srs"]["wkt"]
                bounds = meta["bounds"]
            except:
                bounds = None                            
            geo_dict['Bounds'].append(bounds)    
            geo_dict['WKT'].append(wkt)
            
    with open(json_path,"w") as json_file:
        json.dump(geo_dict,json_file)                 

if __name__ == "__main__":
    get_data(DATASET_PATH,JSON_PATH)

# %% [markdown]
# A bound is an array of 6 numbers
# [xmin, ymin,zmin,xmax,ymax,zmax]
# We want to retain xmin,ymin,xmax,ymax

# %%
df = pd.read_json("../geosome/data/data_usgs.json")
df.head()
# Out:
#                          Region  \
# 0           AK_BrooksCamp_2012/
# 1              AK_Coastal_2009/
# 2  AK_Fairbanks-NSBorough_2010/
# 3               AK_Juneau_2012/
# 4                AK_Kenai_2008/
#
#                                            File_path  \
# 0  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 1  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 2  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 3  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 4  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
#
#                                               Bounds  \
# 0  [-17347360, 8065364, -12414, -17321558, 809116...
# 1  [-15730544, 10937407, -19027, -15691854, 10976...
# 2  [-16471700, 9519129, -45314, -16381190, 960963...
# 3  [-15014449, 8012267, -35030, -14943073, 808364...
# 4  [-16906356, 8303726, -166851, -16570284, 86397...
#
#                                                  WKT
# 0  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 1  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 2  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 3  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 4  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...

# %%
#Drop the z min and z max values
for i in df['Bounds']:
    del i[2]
for i in df['Bounds']:
    del i[4]

# %%
df.sample(5)
# Out:
#                                              Region  \
# 121                            CA_Scripps-Dec_2002/
# 846   USGS_LPC_IL_District4_Tazewell_2014_LAS_2016/
# 321                               KS_SalineCo_2010/
# 272                      IN_Statewide_Opt1_B2_2017/
# 1373       USGS_LPC_TX_Panhandle_B11_2017_LAS_2019/
#
#                                               File_path  \
# 121   https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 846   https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 321   https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 272   https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 1373  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
#
#                                         Bounds  \
# 121   [-13121128, 3873238, -13036268, 3958098]
# 846    [-10014350, 4905136, -9936068, 4983418]
# 321   [-10905618, 4653591, -10834300, 4724909]
# 272     [-9615730, 4820128, -9439430, 4996428]
# 1373  [-11356487, 4225403, -11130793, 4451097]
#
#                                                     WKT
# 121   PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 846   PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 321   PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 272   PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 1373  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...

# %%
polygon = []
for b in df.Bounds:
    MINX,MINY,MAXX,MAXY = [b[0],b[1],b[2],b[3]]
    poly = Polygon(((MINX, MINY), (MINX, MAXY), (MAXX, MAXY), (MAXX, MINY), (MINX, MINY)))
    polygon.append(poly)

# %%
df['geometry'] = polygon
df.head()
# Out:
#                          Region  \
# 0           AK_BrooksCamp_2012/
# 1              AK_Coastal_2009/
# 2  AK_Fairbanks-NSBorough_2010/
# 3               AK_Juneau_2012/
# 4                AK_Kenai_2008/
#
#                                            File_path  \
# 0  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 1  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 2  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 3  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 4  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
#
#                                        Bounds  \
# 0    [-17347360, 8065364, -17321558, 8091166]
# 1  [-15730544, 10937407, -15691854, 10976097]
# 2    [-16471700, 9519129, -16381190, 9609639]
# 3    [-15014449, 8012267, -14943073, 8083643]
# 4    [-16906356, 8303726, -16570284, 8639798]
#
#                                                  WKT  \
# 0  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 1  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 2  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 3  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 4  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
#
#                                             geometry
# 0  POLYGON ((-17347360 8065364, -17347360 8091166...
# 1  POLYGON ((-15730544 10937407, -15730544 109760...
# 2  POLYGON ((-16471700 9519129, -16471700 9609639...
# 3  POLYGON ((-15014449 8012267, -15014449 8083643...
# 4  POLYGON ((-16906356 8303726, -16906356 8639798...

# %%
gdf = geopandas.GeoDataFrame(df)
gdf.head()
# Out:
#                          Region  \
# 0           AK_BrooksCamp_2012/
# 1              AK_Coastal_2009/
# 2  AK_Fairbanks-NSBorough_2010/
# 3               AK_Juneau_2012/
# 4                AK_Kenai_2008/
#
#                                            File_path  \
# 0  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 1  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 2  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 3  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 4  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
#
#                                        Bounds  \
# 0    [-17347360, 8065364, -17321558, 8091166]
# 1  [-15730544, 10937407, -15691854, 10976097]
# 2    [-16471700, 9519129, -16381190, 9609639]
# 3    [-15014449, 8012267, -14943073, 8083643]
# 4    [-16906356, 8303726, -16570284, 8639798]
#
#                                                  WKT  \
# 0  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 1  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 2  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 3  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 4  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
#
#                                             geometry          area  \
# 0  POLYGON ((-17347360.000 8065364.000, -17347360...  6.657432e+08
# 1  POLYGON ((-15730544.000 10937407.000, -1573054...  1.496916e+09
# 2  POLYGON ((-16471700.000 9519129.000, -16471700...  8.192060e+09
# 3  POLYGON ((-15014449.000 8012267.000, -15014449...  5.094533e+09
# 4  POLYGON ((-16906356.000 8303726.000, -16906356...  1.129444e+11
#
#                              centroid  \
# 0   POINT (-17334459.000 8078265.000)
# 1  POINT (-15711199.000 10956752.000)
# 2   POINT (-16426445.000 9564384.000)
# 3   POINT (-14978761.000 8047955.000)
# 4   POINT (-16738320.000 8471762.000)
#
#                                             envelope
# 0  POLYGON ((-17347360.000 8065364.000, -17321558...
# 1  POLYGON ((-15730544.000 10937407.000, -1569185...
# 2  POLYGON ((-16471700.000 9519129.000, -16381190...
# 3  POLYGON ((-15014449.000 8012267.000, -14943073...
# 4  POLYGON ((-16906356.000 8303726.000, -16570284...

# %%
gdf['area'] = gdf.area
# Returns a GeoSeries of points for each geometric centroid.
gdf['centroid'] = gdf.centroid
# Returns a GeoSeries of geometries representing the point or smallest rectangular
# polygon (with sides parallel to the coordinate axes) that contains each object.
gdf['envelope'] = gdf.envelope

# %%
gdf = gdf.drop(['File_path','Bounds'],axis=1)
gdf.sample()
# Out:
#                             Region  \
# 264  IN_Statewide-StJosephCo_2011/
#
#                                                    WKT  \
# 264  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
#
#                                               geometry          area  \
# 264  POLYGON ((-9633542.000 5073893.000, -9633542.0...  3.057648e+09
#
#                              centroid  \
# 264  POINT (-9605894.000 5101541.000)
#
#                                               envelope
# 264  POLYGON ((-9633542.000 5073893.000, -9578246.0...

# %%
gdf.crs = "EPSG:4326"
print(gdf.crs)
# Out:
# EPSG:4326

# %%
gdf.sample()
# Out:
#                    Region                                                WKT  \
# 429  NC_BrunswickCo_2014/  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
#
#                                               geometry          area  \
# 429  POLYGON ((-8755722.000 4001331.000, -8755722.0...  6.558408e+09
#
#                              centroid  \
# 429  POINT (-8715230.000 4041823.000)
#
#                                               envelope
# 429  POLYGON ((-8755722.000 4001331.000, -8674738.0...

# %%
m = folium.Map(location=[37.0902,-95.7129], zoom_start=10, tiles='CartoDB positron')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_93ca7d8d7c5441e89bb7f86d8d4615c3%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_93ca7d8d7c5441e89bb7f86d8d4615c3%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_93ca7d8d7c5441e89bb7f86d8d4615c3%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_93ca7d8d7c5441e89bb7f86d8d4615c3%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.0902%2C%20-95.7129%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
gdf['lat'] = gdf.centroid.y
gdf['lon'] = gdf.centroid.x
gdf.head()
# Out:
# C:\Users\user\Downloads\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   """Entry point for launching an IPython kernel.
# C:\Users\user\Downloads\Anaconda\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#                          Region  \
# 0           AK_BrooksCamp_2012/
# 1              AK_Coastal_2009/
# 2  AK_Fairbanks-NSBorough_2010/
# 3               AK_Juneau_2012/
# 4                AK_Kenai_2008/
#
#                                                  WKT  \
# 0  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 1  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 2  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 3  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 4  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
#
#                                             geometry          area  \
# 0  POLYGON ((-17347360.000 8065364.000, -17347360...  6.657432e+08
# 1  POLYGON ((-15730544.000 10937407.000, -1573054...  1.496916e+09
# 2  POLYGON ((-16471700.000 9519129.000, -16471700...  8.192060e+09
# 3  POLYGON ((-15014449.000 8012267.000, -15014449...  5.094533e+09
# 4  POLYGON ((-16906356.000 8303726.000, -16906356...  1.129444e+11
#
#                              centroid  \
# 0   POINT (-17334459.000 8078265.000)
# 1  POINT (-15711199.000 10956752.000)
# 2   POINT (-16426445.000 9564384.000)
# 3   POINT (-14978761.000 8047955.000)
# 4   POINT (-16738320.000 8471762.000)
#
#                                             envelope         lat         lon
# 0  POLYGON ((-17347360.000 8065364.000, -17321558...   8078265.0 -17334459.0
# 1  POLYGON ((-15730544.000 10937407.000, -1569185...  10956752.0 -15711199.0
# 2  POLYGON ((-16471700.000 9519129.000, -16381190...   9564384.0 -16426445.0
# 3  POLYGON ((-15014449.000 8012267.000, -14943073...   8047955.0 -14978761.0
# 4  POLYGON ((-16906356.000 8303726.000, -16570284...   8471762.0 -16738320.0

# %%
region_list = []
years = []
states = []
for r in gdf.Region:
    r = r.strip("/")
    year = r.split('_')[-1]
    state = r.split('_')[1]
    region_list.append(r)
    years.append(year)
    states.append(state)

# %%
usgs_years = set(years)
print(usgs_years)
# Out:
# {'2016', '2013', '2003', '2014', '2005', '2008', '2009', '1', '2020', '2012', '2006-2008', '2017', '2006', '2019', '2002', 'NewYorkCity', '2015', '2004', '2018', '2011', '2010', 'Statewide-HarrisonCo-2011', '2012-2014', '2007', 'FullState'}

# %%
gdf['Region'] = region_list
gdf['State'] = states
gdf['Year'] = years
gdf.drop(['envelope','lat','lon'],axis=1,inplace=True)
gdf.head()
# Out:
#                         Region  \
# 0           AK_BrooksCamp_2012
# 1              AK_Coastal_2009
# 2  AK_Fairbanks-NSBorough_2010
# 3               AK_Juneau_2012
# 4                AK_Kenai_2008
#
#                                                  WKT  \
# 0  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 1  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 2  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 3  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 4  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
#
#                                             geometry          area  \
# 0  POLYGON ((-17347360.000 8065364.000, -17347360...  6.657432e+08
# 1  POLYGON ((-15730544.000 10937407.000, -1573054...  1.496916e+09
# 2  POLYGON ((-16471700.000 9519129.000, -16471700...  8.192060e+09
# 3  POLYGON ((-15014449.000 8012267.000, -15014449...  5.094533e+09
# 4  POLYGON ((-16906356.000 8303726.000, -16906356...  1.129444e+11
#
#                              centroid                State  Year
# 0   POINT (-17334459.000 8078265.000)           BrooksCamp  2012
# 1  POINT (-15711199.000 10956752.000)              Coastal  2009
# 2   POINT (-16426445.000 9564384.000)  Fairbanks-NSBorough  2010
# 3   POINT (-14978761.000 8047955.000)               Juneau  2012
# 4   POINT (-16738320.000 8471762.000)                Kenai  2008

# %%
options = ['NewYorkCity','Statewide-HarrisonCo-2011','FullState','1']
gdf.loc[gdf['Year'].isin(options)]
# Out:
#                               Region  \
# 227                     IA_FullState
# 255     IN_Statewide-HarrisonCo-2011
# 333                     KY_FullState
# 373                     MN_FullState
# 519                   NY_NewYorkCity
# 751  USGS_LPC_CA_SanDiego_2015_C17_1
#
#                                                    WKT  \
# 227  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 255  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 333  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 373  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 519  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 751  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
#
#                                               geometry          area  \
# 227  POLYGON ((-10758075.000 4793202.000, -10758075...  5.240920e+11
# 255  POLYGON ((-9619086.000 4572539.000, -9619086.0...  4.385883e+09
# 333  POLYGON ((-10309997.000 3793753.000, -10309997...  2.322771e+12
# 373  POLYGON ((-10913529.000 5383547.000, -10913529...  9.177065e+11
# 519  POLYGON ((-8267099.000 4937860.000, -8267099.0...  3.966480e+09
# 751  POLYGON ((-13058061.000 3836206.000, -13058061...  1.360022e+10
#
#                               centroid                      State  \
# 227  POINT (-10396104.000 5155173.000)                  FullState
# 255   POINT (-9585973.000 4605652.000)  Statewide-HarrisonCo-2011
# 333   POINT (-9547965.000 4555785.000)                  FullState
# 373  POINT (-10434544.000 5862532.000)                  FullState
# 519   POINT (-8235609.000 4969350.000)                NewYorkCity
# 751  POINT (-12999751.000 3894516.000)                        LPC
#
#                           Year
# 227                  FullState
# 255  Statewide-HarrisonCo-2011
# 333                  FullState
# 373                  FullState
# 519                NewYorkCity
# 751                          1

# %%
gdf = gdf.drop(gdf.index[[227,255,333,373,519,751]])
