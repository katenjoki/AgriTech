# %%
import json
import pandas as pd
import pdal

# %%
files = pd.read_csv("../filename.txt",header=None)
files.columns = ['Region']
files.head()
# Out:
#                          Region
# 0           AK_BrooksCamp_2012/
# 1              AK_Coastal_2009/
# 2  AK_Fairbanks-NSBorough_2010/
# 3               AK_Juneau_2012/
# 4                AK_Kenai_2008/

# %%
geo_dict = {'Region':[],
           'Path':[],
           'Geometry':[],
           'Bounds':[]
           }
dataset_path = "https://s3-us-west-2.amazonaws.com/usgs-lidar-public/"
with open('../filename.txt') as filenames:
    for f in filenames:
        file = dataset_path + f + "ept.json"
        geo_dict['Region'].append(file)
        try:
            meta = json.load(urllib.urlopen(file))
            wkt = meta['srs']['wkt']
            bounds = meta['bounds']
        except:
            wkt = None
            bounds = None
        geo_dict['Geometry'].append(wkt)
        geo_dict['Bounds'].append(bounds)

# %%
data = pd.DataFrame(geo_dict)
data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_24420/2829306878.py in <module>
# ----> 1 data = pd.DataFrame(geo_dict)
#       2 data.head()
#
# /opt/miniconda/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# /opt/miniconda/lib/python3.9/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     460         # TODO: can we get rid of the dt64tz special case above?
#     461
# --> 462     return arrays_to_mgr(
# ...

# %%
file_path
# Out:
# ['https://s3-us-west-2.amazonaws.com/usgs-lidar-public/AK_BrooksCamp_2012/ept.json',
#  'https://s3-us-west-2.amazonaws.com/usgs-lidar-public/AK_Coastal_2009/ept.json',
#  'https://s3-us-west-2.amazonaws.com/usgs-lidar-public/AK_Fairbanks-NSBorough_2010/ept.json',
#  'https://s3-us-west-2.amazonaws.com/usgs-lidar-public/AK_Juneau_2012/ept.json',
#  'https://s3-us-west-2.amazonaws.com/usgs-lidar-public/AK_Kenai_2008/ept.json',
#  'https://s3-us-west-2.amazonaws.com/usgs-lidar-public/AK_MatanuskaSusitna-Lot1_2011/ept.json',
#  'https://s3-us-west-2.amazonaws.com/usgs-lidar-public/AK_MatanuskaSusitna-Lot2_2011/ept.json',
#  'https://s3-us-west-2.amazonaws.com/usgs-lidar-public/AK_NomeCreek_2010/ept.json',
#  'https://s3-us-west-2.amazonaws.com/usgs-lidar-public/AK_NorthSlope_B10_2018/ept.json',
#  'https://s3-us-west-2.amazonaws.com/usgs-lidar-public/AK_NorthSlope_B11_2018/ept.json',
#  'https://s3-us-west-2.amazonaws.com/usgs-lidar-public/AK_NorthSlope_B12_2018/ept.json',
# ...
