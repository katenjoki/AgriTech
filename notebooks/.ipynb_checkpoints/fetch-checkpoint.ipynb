# %%
import json
import pandas as pd
import pdal
import urllib
from urllib.request import urlopen
import shapely
from shapely.geometry import Polygon
import geopandas
import laspy
import rasterio
from rasterio.plot import show
from rasterio import mask
import folium
import fiona

# %%
x = geopandas.read_file('../geosome/shp/IA_FullState.shp')
x.plot(cmap='jet',column='NAME_4')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_30872/1219697715.py in <module>
# ----> 1 x = geopandas.read_file('../geosome/shp/IA_FullState.shp')
#       2 x.plot(cmap='jet',column='NAME_4')
#
# /opt/miniconda/lib/python3.9/site-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#     138         # zipped file. In order to match that behavior, attempt to add a zip scheme
#     139         # if missing.
# --> 140         if _is_zip(str(filename)):
#     141             parsed = fiona.parse_path(str(filename))
#     142             if isinstance(parsed, fiona.path.ParsedPath):
#
# /opt/miniconda/lib/python3.9/site-packages/geopandas/io/file.py in _is_zip(path)
#      56 def _is_zip(path):
#      57     """Check if a given path is a zipfile"""
# ---> 58     parsed = fiona.path.ParsedPath.from_uri(path)
#      59     return (
#      60         parsed.archive.endswith(".zip")
#
# AttributeError: module 'fiona' has no attribute 'path'

# %%
from glob import glob
def get_shp_from_tif(tif_path:str, shp_file_path:str) -> None:
    raster = rasterio.open(tif_path)
    bounds = raster.bounds

    df = geopandas.GeoDataFrame({"id":1,"geometry":[box(*bounds)]})
   
    # save to file
    df.to_file(shp_file_path)
    print('Saved..')

# %%
from shapely.geometry import box
get_shp_from_tif('../geosome/tif/IA_FullState.tif', shp_file_path='../geosome/shp/combi.shp')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_30498/120585523.py in <module>
#       1 from shapely.geometry import box
# ----> 2 get_shp_from_tif('../geosome/tif/IA_FullState.tif', shp_file_path='../geosome/shp/combi.shp')
#
# /tmp/ipykernel_30498/171461768.py in get_shp_from_tif(tif_path, shp_file_path)
#       7
#       8     # save to file
# ----> 9     df.to_file(shp_file_path)
#      10     print('Saved..')
#
# /opt/miniconda/lib/python3.9/site-packages/geopandas/geodataframe.py in to_file(self, filename, driver, schema, index, **kwargs)
#    1084         from geopandas.io.file import _to_file
#    1085
# -> 1086         _to_file(self, filename, driver, schema, index, **kwargs)
#    1087
#    1088     def set_crs(self, crs=None, epsg=None, inplace=False, allow_override=False):
#
# /opt/miniconda/lib/python3.9/site-packages/geopandas/io/file.py in _to_file(df, filename, driver, schema, index, mode, crs, **kwargs)
#     315         )
#     316
# --> 317     with fiona_env():
#     318         crs_wkt = None
#     319         try:
#
# TypeError: 'NoneType' object is not callable

# %%
#import sys
#sys.path.append("../geosome/")
from geosome import geo_fetch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_27177/613457937.py in <module>
#       1 #import sys
#       2 #sys.path.append("../geosome/")
# ----> 3 from geosome import geo_fetch
#
# ModuleNotFoundError: No module named 'geosome'

# %%
load = load_file("([-10425171.940, -10423171.940], [5164494.710, 5166494.710])","IA_FullState/")
load.get_raster_terrain()

# %%
DATASET_PATH = "https://s3-us-west-2.amazonaws.com/usgs-lidar-public/"
JSON_PATH = "../data/data_usgs.json"
        
def get_data(dataset_path:str,json_path:str):
    geo_dict = {'Region':[],
                'File_path':[],
                'Bounds':[],
                'WKT':[]
                }
    with open('../filename.txt') as filenames:
        for f in filenames:
            f = f.strip('\n')
            geo_dict['Region'].append(f)
            file = dataset_path + f +"ept.json"
            geo_dict['File_path'].append(file)
            try:
                meta = json.load(urlopen(file))
                wkt = meta["srs"]["wkt"]
                bounds = meta["bounds"]
            except:
                bounds = None                            
            geo_dict['Bounds'].append(bounds)    
            geo_dict['WKT'].append(wkt)
            
    with open(json_path,"w") as json_file:
        json.dump(geo_dict,json_file)                 

if __name__ == "__main__":
    get_data(DATASET_PATH,JSON_PATH)

# %% [markdown]
# A bound is an array of 6 numbers
# [xmin, ymin,zmin,xmax,ymax,zmax]
# We want to retain xmin,ymin,xmax,ymax

# %%
df = pd.read_json("../data/data_usgs.json")
df.head()
# Out:
#                          Region  \
# 0           AK_BrooksCamp_2012/
# 1              AK_Coastal_2009/
# 2  AK_Fairbanks-NSBorough_2010/
# 3               AK_Juneau_2012/
# 4                AK_Kenai_2008/
#
#                                            File_path  \
# 0  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 1  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 2  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 3  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 4  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
#
#                                               Bounds  \
# 0  [-17347360, 8065364, -12414, -17321558, 809116...
# 1  [-15730544, 10937407, -19027, -15691854, 10976...
# 2  [-16471700, 9519129, -45314, -16381190, 960963...
# 3  [-15014449, 8012267, -35030, -14943073, 808364...
# 4  [-16906356, 8303726, -166851, -16570284, 86397...
#
#                                                  WKT
# 0  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 1  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 2  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 3  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 4  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...

# %%
y=[]
for r in df['Region']:
    x = r.strip('/')
    y.append(x)
y
# Out:
# ['AK_BrooksCamp_2012',
#  'AK_Coastal_2009',
#  'AK_Fairbanks-NSBorough_2010',
#  'AK_Juneau_2012',
#  'AK_Kenai_2008',
#  'AK_MatanuskaSusitna-Lot1_2011',
#  'AK_MatanuskaSusitna-Lot2_2011',
#  'AK_NomeCreek_2010',
#  'AK_NorthSlope_B10_2018',
#  'AK_NorthSlope_B11_2018',
#  'AK_NorthSlope_B12_2018',
#  'AK_NorthSlope_B13_2018',
#  'AK_NorthSlope_B14_2018',
#  'AK_NorthSlope_B1_2018',
#  'AK_NorthSlope_B2_2018',
#  'AK_NorthSlope_B3_2018',
#  'AK_NorthSlope_B4_2018',
#  'AK_NorthSlope_B5_2018',
#  'AK_NorthSlope_B6_2018',
#  'AK_NorthSlope_B7_2018',
#  'AK_NorthSlope_B8_2018',
#  'AK_NorthSlope_B9_2018',
#  'AK_ValdezB_2007',
#  'AK_Valdez_2007',
#  'AK_YukonFlats_2009',
#  'AL_25Co_TL_2017',
#  'AL_BaldwinCo-East_2011',
#  'AL_BaldwinCo-West_2011',
#  'AL_BlountCo_2010',
#  'AL_ColbertLauderdale_2011',
#  'AL_NorthAL_2019',
#  'AL_TriCounty_2010',
#  'AR-TN_NRCS_CaneCreek_2010',
#  'AR-TN_NRCS_Sharkey_2010',
#  'ARRA-AK_EkluntaGlacier_2010',
#  'ARRA-AL_MobileBay_2010',
#  'ARRA-AL_TennesseeRiver_2010',
#  'ARRA-CA_CentralCoast-Z3_2010',
#  'ARRA-CA_CentralCoast-Z4_2010',
#  'ARRA-CA_ChannelIslands-10_2010',
#  'ARRA-CA_ChannelIslands-11_2010',
#  'ARRA-CA_GoldenGate_2010',
#  'ARRA-CA_SanFranCoast_2010',
#  'ARRA-CO_GrandCo_2010',
#  'ARRA-FL_Charlotte-E_2010',
#  'ARRA-FL_Charlotte-W_2010',
#  'ARRA-FL_KissimmeeRiver_2011',
#  'ARRA-FL_LibertyCo_2010',
#  'ARRA-FL_SuwanneeRiver_2011',
#  'ARRA-FL_UpperStJohnsRiver_2010',
#  'ARRA-GA_LakeLanier_2010',
#  'ARRA-IL_LakeCo_2007',
#  'ARRA-IN_Flood_2010',
#  'ARRA-LA_Coastal-Z15_2011',
#  'ARRA-LA_Coastal-Z16_2011',
#  'ARRA-LFTNE_ConnecticutZ18_2010',
#  'ARRA-LFTNE_ConnecticutZ19_2011',
#  'ARRA-LFTNE_Massachusetts_2011',
#  'ARRA-LFTNE_NewHampshire_2011',
#  'ARRA-LFTNE_NewYork_2010',
#  'ARRA-LFTNE_RhodeIsland_2011',
#  'ARRA-MI_4SECounties_2010',
#  'ARRA-MI_LowerPeninsula_2010',
#  'ARRA-MI_TriCounty_2010',
#  'ARRA-MO_StoneCo_2010',
#  'ARRA-NE_PlatteRiver_2010',
#  'ARRA-NJ_3Counties_2010',
#  'ARRA-NRCS_Illinois_2010',
#  'ARRA-NRCS_Kentucky_2010',
#  'ARRA-OR_SandyRiver_2010',
#  'ARRA-SC_AllendaleCo_2010',
#  'ARRA-SC_BambergCo_2010',
#  'ARRA-SC_HamptonCo_2010',
#  'ARRA-SC_LeeCo_2010',
#  'ARRA-TN_SmokyMtns_2011',
#  'ARRA-TX_CalhounCo_2010',
#  'ARRA-TX_HidalgoCo_2010',
#  'ARRA-TX_NuecesCo_2010',
#  'ARRA-TX_WilacyCo_2010',
#  'ARRA-WI_BrownCo_2010',
#  'AR_BuffaloRiver_2009',
#  'AR_BuffaloRiver_2010',
#  'AR_Dardanelle_2011',
#  'AR_FEMA-ChicotDesha_2011',
#  'AR_FEMA-VI-BayouMeto_2012',
#  'AR_LowerStFrancisRiver-FEMA_2012',
#  'AR_McKinneyPosten_2011',
#  'AR_PAgis_2010',
#  'AR_UpperBlackWatershed-FEMA_2012',
#  'AR_UpperWhiteVillage-FEMA_2012',
#  'AZ_Black_Mesa_CoalMine_2012',
#  'AZ_BrawleyRillito_TL_2018',
#  'AZ_Cochise-FEMA_2012',
#  'AZ_CochiseCounty_2_2020',
#  'AZ_Coconino_B1_2019',
#  'AZ_FEMA_Central_2017',
#  'AZ_FEMA_East_2017',
#  'AZ_NavajoCorridor_1_2020',
#  'AZ_NorthKaibabNF_B1_2019',
#  'AZ_OrganPipeCactusNM_1_2020',
#  'AZ_SanCarlosReservation_2013',
#  'AZ_Tucson_2011',
#  'CA_AlamedaCo_2006',
#  'CA_CalaverasTuolumne_2011',
#  'CA_ContraCostaCo_2007',
#  'CA_DayFire_2007',
#  'CA_FEMAR9Estrella_2019',
#  'CA_FEMAR9PanocheSanLuis_2019',
#  'CA_FEMA_Z1_2018',
#  'CA_FEMA_Z4_B1_2018',
#  'CA_FEMA_Z4_B2_2018',
#  'CA_FEMA_Z4_QL1_2018',
#  'CA_MountainPass_B1_2019',
#  'CA_NoCAL_Wildfires_TL_QL1_2018',
#  'CA_NoCAL_Wildfires_TL_QL2_2018',
#  'CA_OrangeCo_2011',
#  'CA_PlacerCo_2012',
#  'CA_SaltonSea_2010',
#  'CA_SantaClaraCounty_2020',
#  'CA_Scripps-Apr_2004',
#  'CA_Scripps-Apr_2005',
#  'CA_Scripps-Dec_2002',
#  'CA_Scripps-Mar_2003',
#  'CA_Scripps-Mar_2006',
#  'CA_Scripps-May_2002',
#  'CA_Scripps-Oct_2003',
#  'CA_Scripps-Oct_2005',
#  'CA_Scripps-Sep_2002',
#  'CA_Scripps-Sep_2004',
#  'CO_ArkansasValley_2010',
#  'CO_CentralEasternPlains_1_2020',
#  'CO_CentralEasternPlains_2_2020',
#  'CO_DenverDNC_2008',
#  'CO_Denver_2008',
#  'CO_Eastern_B1_2018',
#  'CO_Eastern_B2_QL1_Central_2018',
#  'CO_Eastern_B2_QL2_Central_2018',
#  'CO_Eastern_B2_QL2_North_2018',
#  'CO_Eastern_B3_2018',
#  'CO_Eastern_B4_2018',
#  'CO_Eastern_B5_2018',
#  'CO_Eastern_South_Priority2_2018',
#  'CO_NESEColorado_1_2019',
#  'CO_NESEColorado_2_2019',
#  'CO_NESEColorado_3_2019',
#  'CO_NESEColorado_4_2019',
#  'CO_San-Luis-Valley_2011',
#  'CO_SanLuisJuanMiguel_1_2020',
#  'CO_SanLuisJuanMiguel_2_2020',
#  'CO_SanLuisJuanMiguel_3_2020',
#  'CO_Southwest_NRCS_B1_2018',
#  'CO_Southwest_NRCS_B2_2018',
#  'CO_Southwest_NRCS_B3_2018',
#  'CO_Southwest_NRCS_TL_2018',
#  'CO_WestCentral_2019',
#  'CT_Statewide_B1_2016',
#  'CT_Statewide_B2_2016',
#  'CT_Statewide_B3_2016',
#  'CT_Statewide_B4_2016',
#  'CT_Statewide_B5_2016',
#  'CT_Statewide_B6_2016',
#  'CT_Statewide_B7_2016',
#  'FL_CharlotteCounty_2007',
#  'FL_ClayPutnam_2007',
#  'FL_DuvalCo_2007',
#  'FL_Elgin_2006-2008',
#  'FL_EscambiaCo_2006',
#  'FL_FlaglerCo_2004',
#  'FL_FranklinCo_2007',
#  'FL_Gulf_2007',
#  'FL_HerbHooverDike_2007',
#  'FL_HillsboroughCo-Lot2_2011',
#  'FL_HillsboroughCo_2007',
#  'FL_HurricaneMichael_2_2020',
#  'FL_IndianRiver_2007',
#  'FL_JeffersonCo-North_2007',
#  'FL_LeeCounty_2007',
#  'FL_LeonCo_2009',
#  'FL_ManateeCo_2007',
#  'FL_NWFWMD_5-Counties_2007',
#  'FL_NassauCo_2007',
#  'FL_OkaloosaCo_2007',
#  'FL_OkaloosaCo_2008',
#  'FL_Panhandle_TL_2018',
#  'FL_PascoCo_2007',
#  'FL_PascoCo_2011',
#  'FL_Peninsular_FDEM_Clay_2018',
#  'FL_Peninsular_FDEM_Desoto_2018',
#  'FL_Peninsular_FDEM_Duval_2018',
#  'FL_Peninsular_FDEM_Glades_2018',
#  'FL_Peninsular_FDEM_Manatee_2018',
#  'FL_Peninsular_FDEM_Nassau_2018',
#  'FL_Peninsular_FDEM_Orange_2018',
#  'FL_Peninsular_Flagler_2019',
#  'FL_Peninsular_Hernando_2019',
#  'FL_Peninsular_Pinellas_2018',
#  'FL_Peninsular_Sumter_2018',
#  'FL_PinellasCo_2007',
#  'FL_Sarasota_2007',
#  'FL_StJohnsCo_2008',
#  'FL_StJohnsRiver_WMD_2012',
#  'FL_SuwanneeRiver-Area1_2013',
#  'FL_SuwanneeRiver-Area2_2013',
#  'FL_SuwanneeRiver-Area3_2013',
#  'FL_SuwanneeRiver-Area4_2013',
#  'FL_SuwanneeRiver-FY12-Area4-5_2013',
#  'FL_SuwanneeRiver_2012',
#  'FL_SuwanneeRiver_2013',
#  'FL_SuwanneeRiver_North_2011',
#  'FL_SuwanneeRiver_West_2011',
#  'FL_WaltonAFB_2006-2008',
#  'FL_WaltonCo_2006',
#  'GA_Bibb_Jasper_Jones_Monroe_2010',
#  'GA_Bryan_County_2010',
#  'GA_Camden_County_2010',
#  'GA_Central_2_2018',
#  'GA_Charlton_Brantley_Camden_2010',
#  'GA_Effingham_Screven_Bulloch_2010',
#  'GA_Harris_County_2010',
#  'GA_Heard_County_2010',
#  'GA_McIntosh_County_2010',
#  'GA_PotatoCreek_2009',
#  'GA_Statewide_B1_2018',
#  'GA_Walton_County_2010',
#  'GA_WayneCo_2010',
#  'GA_Wayne_Long_McIntosh_2010',
#  'Guam_2012',
#  'IA_FullState',
#  'IA_SouthCentral_1_2020',
#  'ID_CityofRocks_2011',
#  'ID_CoeurDAlene_2009',
#  'ID_DryCreek_2007',
#  'ID_USGSTributary_2008',
#  'IL_8County_B1_2020',
#  'IL_8County_B2_2020',
#  'IL_8County_PlusChampaign_B1_2019',
#  'IL_BooneCo_2007',
#  'IL_HenryCo_2009',
#  'IL_Johnson-Pulaski_MassacCos_2012-2014',
#  'IL_KendallCo_2010',
#  'IL_Peoria_2008',
#  'IL_SalineRiver_2010',
#  'IL_SangamonRiver_2011',
#  'IL_Wabash-Saline-FEMA_2011',
#  'IL_WabashRiver_2010',
#  'IN_LakeErie_2010',
#  'IN_Statewide-BartholomewCo_2011',
#  'IN_Statewide-BooneCo_2011',
#  'IN_Statewide-BrownCo_2011',
#  'IN_Statewide-CarrollCo_2011',
#  'IN_Statewide-CassCo_2011',
#  'IN_Statewide-ClintonCo_2011',
#  'IN_Statewide-CrawfordCo_2011',
#  'IN_Statewide-ElkhartCo_2011',
#  'IN_Statewide-FultonCo_2011',
#  'IN_Statewide-HarrisonCo-2011',
#  'IN_Statewide-HowardCo_2011',
#  'IN_Statewide-JacksonCo_2011',
#  'IN_Statewide-KosciuskoCo_2011',
#  'IN_Statewide-LawrenceCo_2011',
#  'IN_Statewide-MarshallCo_2011',
#  'IN_Statewide-MiamiCo_2011',
#  'IN_Statewide-OrangeCo_2011',
#  'IN_Statewide-PulaskiCo_2011',
#  'IN_Statewide-StJosephCo_2011',
#  'IN_Statewide-StarkeCo_2011',
#  'IN_Statewide-TiptonCo_2011',
#  'IN_Statewide-WabashCo_2011',
#  'IN_Statewide-WashingtonCo_2011',
#  'IN_Statewide_B1_2017',
#  'IN_Statewide_B2_2017',
#  'IN_Statewide_Opt1_B1_2017',
#  'IN_Statewide_Opt1_B2_2017',
#  'IN_Statewide_Opt1_B3_2017',
#  'IN_Statewide_Opt1_B4_2017',
#  'IN_Statewide_Opt1_B5_2017',
#  'IN_Statewide_Opt2_B1_2017',
#  'IN_Statewide_Opt2_B2_2017',
#  'IN_Statewide_Opt2_B3_2017',
#  'IN_Statewide_Opt2_B4_2017',
#  'IN_Statewide_Opt2_B5_2017',
#  'IN_Statewide_Opt2_B6_2017',
#  'KS_Area1_2012',
#  'KS_Area3-ButlerCo_2012',
#  'KS_Area3-NortheastA_2012',
#  'KS_Area3-NortheastB_2012',
#  'KS_Area3-Southeast_2012',
#  'KS_AtchinsonCo_2010',
#  'KS_BartonCo_2010',
#  'KS_ChaseCo_2010',
#  'KS_Coffey_2010',
#  'KS_DickinsonCo_2010',
#  'KS_DodgeCity_2010',
#  'KS_DouglasCounty_2006',
#  'KS_EllsworthCo_2010',
#  'KS_Franklin_2010',
#  'KS_FtRiley_2006',
#  'KS_Geary_2010',
#  'KS_HarveyCo2_2010',
#  'KS_HarveyCo_2010',
#  'KS_JacksonCo_2006',
#  'KS_JeffersonCo_2006',
#  'KS_JewellCo_2010',
#  'KS_JohnsonCo_2006',
#  'KS_Leavenworth_2006',
#  'KS_Leavenworth_2010',
#  'KS_LincolnCo_2010',
#  'KS_LyonCo_2010',
#  'KS_Manhattan_2006',
#  'KS_MarionCo_2010',
#  'KS_MarshallCo_2010',
#  'KS_McPhersonCo_2010',
#  'KS_MiamiCo_2009',
#  'KS_MitchellCo_2010',
#  'KS_MorrisCo_2010',
#  'KS_NorthCentral_2009',
#  'KS_Osage_2010',
#  'KS_OttawaCo_2010',
#  'KS_PottawatomieCo_2010',
#  'KS_RiceCo_2010',
#  'KS_Riley_2010',
#  'KS_SalineCo_2010',
#  'KS_Sedgwick-Wichita_2008',
#  'KS_ShawneeCounty_2006',
#  'KS_Statewide_B10_2018',
#  'KS_Statewide_B11_2018',
#  'KS_Statewide_B13_2018',
#  'KS_Statewide_B2_2018',
#  'KS_Statewide_B4_2018',
#  'KS_Statewide_B7_2018',
#  'KS_USFWS_2010',
#  'KY_Eastern_B1_2019',
#  'KY_Eastern_B2_2019',
#  'KY_FullState',
#  'LA_Atchafalaya2_2013',
#  'LA_AtchafalayaBasin_2010',
#  'LA_Bayou_Nezpique_TL_2018',
#  'LA_CPRA_B1_2019',
#  'LA_CPRA_B2_2019',
#  'LA_CPRA_B3_2019',
#  'LA_CPRA_B4_2019',
#  'LA_CPRA_B5_2019',
#  'LA_Jean-Lafitte_2013',
#  'LA_Sabine_River_Lidar_A1_2018',
#  'LA_Sabine_River_Lidar_A2_2018',
#  'LA_Sabine_River_Lidar_A3_2018',
#  'LA_Sabine_River_Lidar_A4_2018',
#  'LA_Sabine_River_Lidar_A5_2018',
#  'MD_Baltimore_2008',
#  'MD_CalvertCo_2011',
#  'MD_FEMA_AlleganyCo_2012',
#  'MD_FEMA_HoopersIsland_2011',
#  'MD_FEMA_WashingtonCounty_2012',
#  'MD_FEMA_WorcesterCo_2011',
#  'MD_GoldenBeach_2012',
#  'MD_Kent_QueenAnne_Caroline_2006',
#  'MD_NRCS-LiDAR_2012',
#  'ME_Androscoggin_2009',
#  'ME_AroostookCo_2012',
#  'ME_Augusta_2006',
#  'ME_CrownofMaine_B2_2018',
#  'MI_Charlevoix_Islands_TL_2018',
#  'MI_DickinsonCo-NRCS_2012',
#  'MI_FEMA_Alcona_Oscoda_2019',
#  'MI_FEMA_Cheboygan_2019',
#  'MI_FEMA_Chippewa_2019',
#  'MI_FEMA_Crawford_Kalkaska_2019',
#  'MI_FEMA_Gogebic_2019',
#  'MI_LakeErie_UTM16_2010',
#  'MI_LakeErie_UTM17_2010',
#  'MI_SaginawBay_2011',
#  'MN_ChippewaCo_2010',
#  'MN_CottonwoodCo_2010',
#  'MN_FullState',
#  'MN_KandiyohiCo_2010',
#  'MN_LakeCounty_2018',
#  'MN_MurrayCo_2010',
#  'MN_RenvilleCo_2010',
#  'MN_RockCo_2010',
#  'MN_SibleyCo_2010',
#  'MN_SwiftCo_2010',
#  'MN_WasecaCo_2010',
#  'MO_AdairCo_2011',
#  'MO_BarryCo_2011',
#  'MO_BooneCo_2009',
#  'MO_Clay_County_2008',
#  'MO_Cole-Callaway-Osage_2010',
#  'MO_CooperCo_2011',
#  'MO_DuckCreek_2009',
#  'MO_DunklinCo_2012',
#  'MO_FranklinCo_2011',
#  'MO_GreeneCo_2011',
#  'MO_HowardCo_2011',
#  'MO_JasperCo_2010',
#  'MO_JeffersonGenevieve_2010',
#  'MO_LincolnCo_2011',
#  'MO_LivingstonCo_2011',
#  'MO_LivingstonCounty_2011',
#  'MO_MaconCo_2011',
#  'MO_MonroeAudrainMontgomeryCos_2011',
#  'MO_Platte_County_2008',
#  'MO_PutnamCo_2011',
#  'MO_RandolphCo_2012',
#  'MO_RayCo_2011',
#  'MO_Rolla_2011',
#  'MO_StFrancoisCo_2011',
#  'MO_StFrancois_2012',
#  'MO_StLouis_2012',
#  'MO_Steelville_2011',
#  'MO_SullivanCo_2012',
#  'MO_UpperGrand_2011',
#  'MO_Washinton-IronCo_2011',
#  'MO_WestCentral_1_2018',
#  'MO_WestCentral_2_2018',
#  'MO_WestCentral_3_2018',
#  'MO_WestCentral_4_2018',
#  'MS_CampShelby_2006',
#  'MS_MSDeltaYazoo-Phase1_2009',
#  'MS_MississippiDelta_A1_2018',
#  'MS_MississippiDelta_A2_2018',
#  'MS_NRCS-Lauderdale_2013',
#  'MS_NRCS_East_1_2018',
#  'MS_Tupelo_2012',
#  'MT_Helena_2012',
#  'MT_NRCS_B1_QL1_2018',
#  'MT_NRCS_B1_QL2_2018',
#  'MT_NRCS_B2_2018',
#  'MT_SageGrouse_2010',
#  'NC_BladenCo_2014',
#  'NC_BrunswickCo_2014',
#  'NC_ColumbusCo_2014',
#  'NC_DuplinCo_2014',
#  'NC_EdgecombeCo_2014',
#  'NC_FranklinCo_2014',
#  'NC_GreeneCo_2014',
#  'NC_HalifaxCo_2014',
#  'NC_HurricaneFlorence_1_2020',
#  'NC_HurricaneFlorence_3_2020',
#  'NC_JohnstonCo_2014',
#  'NC_LenoirCo_2014',
#  'NC_NashCo_2014',
#  'NC_NewHanoverCo_2014',
#  'NC_PenderCo_2014',
#  'NC_RobesonCo_2014',
#  'NC_SampsonCo_2014',
#  'NC_VanceCo_2014',
#  'NC_WarrenCo_2014',
#  'NC_WayneCo_2014',
#  'NC_WilsonCo_2014',
#  'NE_CumingCo_2010',
#  'NE_NIROC-PapioCo_2010',
#  'NE_Northeast_1_2020',
#  'NE_Northeast_2_2020',
#  'NE_Northeast_3_2020',
#  'NE_PostSpringFlood_OrthoLidar_B1_2019',
#  'NE_Rainwater-1_2009',
#  'NE_Rainwater-2_2009',
#  'NE_SouthernNE_B1_2018',
#  'NE_SouthernNE_B2_2018',
#  'NE_SouthernNE_B3_2018',
#  'NE_SouthernNE_B4A_2018',
#  'NE_SouthernNE_B4B_2018',
#  'NE_SouthernNE_B5_2018',
#  'NH_Coastal_2_2019',
#  'NJ_CapeMayCo_2008',
#  'NJ_CumberlandCo_2008',
#  'NJ_GloucesterCo_2007',
#  'NJ_SalemCo_2008',
#  'NJ_SalemCo_2009',
#  'NJ_South_Jersey_FEMA_2018',
#  'NJ_SouthernNJ_2018',
#  'NJ_SussexWarren_2008',
#  'NM_Albuquerque_2010',
#  'NM_McKinley_CoalMine_2012',
#  'NM_NRCS_MiddleRioGrande_2017',
#  'NM_Navajo-Pinabete_CoalMine_2012',
#  'NM_NorthWest_B1_2018',
#  'NM_NorthWest_B2A_2018',
#  'NM_NorthWest_B2B_2018',
#  'NM_NorthWest_B3B_2018',
#  'NM_NorthWest_B4_2018',
#  'NM_NorthWest_Jicarilla_TL_2018',
#  'NM_NorthWest_Navajo_A_TL_2018',
#  'NM_NorthWest_Navajo_B_TL_2018',
#  'NM_NorthWest_SouthernUte_TL_2018',
#  'NM_NorthWest_UteMountain_TL_2018',
#  'NM_NorthWest_Zuni_TL_2018',
#  'NM_Northeast_B1_2018',
#  'NM_Northeast_B2_2018',
#  'NM_Northeast_B3_2018',
#  'NM_Northeast_B4_2018',
#  'NM_Northeast_B5_2018',
#  'NM_RioSanJose_TL_2016',
#  'NM_SouthCentral_Acoma_TL_2018',
#  'NM_SouthCentral_B10_2018',
#  'NM_SouthCentral_B1_2018',
#  'NM_SouthCentral_B2_2018',
#  'NM_SouthCentral_B3_2018',
#  'NM_SouthCentral_B4_2018',
#  'NM_SouthCentral_B5_2018',
#  'NM_SouthCentral_B6_2018',
#  'NM_SouthCentral_B7_2018',
#  'NM_SouthCentral_B8_2018',
#  'NM_SouthCentral_B9_2018',
#  'NM_SouthCentral_Fort_Sill_TL_2018',
#  'NM_SouthCentral_Navajo_A_TL_2018',
#  'NM_SouthCentral_Navajo_B_TL_2018',
#  'NM_SouthCentral_Zuni_TL_2018',
#  'NM_SouthEast_B1_2018',
#  'NM_SouthEast_B3_2018',
#  'NM_SouthEast_B4_2018',
#  'NM_SouthEast_B5_2018',
#  'NM_SouthEast_B8_2018',
#  'NM_WhiteSandsNM_2020',
#  'NV_ClarkCounty_B1_2018',
#  'NV_LasVegasValley_2010',
#  'NY_3County_2019',
#  'NY_Columbia_Rensselaer_2016',
#  'NY_FEMAR2_Central_B1_2018',
#  'NY_NewYorkCity',
#  'NY_Region2Lot1-FEMA_2012',
#  'OH_Statewide_Phase1_1_2019',
#  'OH_Statewide_Phase1_2_2019',
#  'OH_Statewide_Phase1_4_2019',
#  'OK_GrandLake_2010',
#  'OK_McIntosh_2011',
#  'OK_Panhandle_B1A_2018',
#  'OK_Panhandle_B1B_2018',
#  'OK_Panhandle_B1C_2018',
#  'OK_Panhandle_B2_2018',
#  'OK_Pottawatomie_2011',
#  'OK_Stillwater_2010',
#  'OK_WashitaRiver_14NAD83_2009',
#  'OK_WashitaRiver_14WGS84_2009',
#  'OK_WashitaRiver_UTM15_2009',
#  'OR_Klamath_2018',
#  'OR_Malheur_USFS_2010',
#  'OR_PoleCreek_2013',
#  'PA_3_County_South_Central_2018',
#  'PA_Northcentral_B1_2019',
#  'PA_Northcentral_B2_2019',
#  'PA_Northcentral_B3QL1_2019',
#  'PA_Northcentral_B3_2019',
#  'PA_Northcentral_B4_2019',
#  'PA_Northcentral_B5_2019',
#  'PA_WesternPA_1_2019',
#  'PA_WesternPA_2_2019',
#  'PA_WesternPA_3_2019',
#  'PA_WesternPA_4_2019',
#  'PR_PuertoRico_2016_LAS_2017',
#  'SC_AndersonCo_2011',
#  'SC_BerkeleyCo_2009',
#  'SC_Berkeley_B2_2016',
#  'SC_CherokeeCo_2008',
#  'SC_ChesterCo_2008',
#  'SC_ChesterfieldCo_2008',
#  'SC_ClarendonCo_2008',
#  'SC_DarlingtonCo_2008',
#  'SC_DillonCo_2008',
#  'SC_FairfieldCo_2008',
#  'SC_FlorenceCo_2009',
#  'SC_GreenwoodCo_2008',
#  'SC_Kershaw_2010',
#  'SC_LancasterCo_2008',
#  'SC_LaurensCo_2008',
#  'SC_LexingtonCo_2010',
#  'SC_MarionCo_2008',
#  'SC_MarlboroCo_2008',
#  'SC_NewberryCo_2008',
#  'SC_OconeeCo_2011',
#  'SC_OrangeburgCo_2008',
#  'SC_PickensCo_2011',
#  'SC_RichlandCo_2010',
#  'SC_SaludaCo_2010',
#  'SC_SavannahPeeDee_1_2019',
#  'SC_SavannahPeeDee_2_2019',
#  'SC_SavannahPeeDee_3_2019',
#  'SC_SavannahPeeDee_4_2019',
#  'SC_UnionCo_2008',
#  'SC_WilliamsburgCo_2008',
#  'SC_YorkCo_2011',
#  'SD_Beadle_County_2012',
#  'SD_Brookings_2012',
#  'SD_Clark_County_2012',
#  'SD_Clay_County_2012',
#  'SD_Codington_County_2012',
#  'SD_Davison_County_2012',
#  'SD_Deuel_County_2012',
#  'SD_EasternSD_1_2020',
#  'SD_Grant_County_2012',
#  'SD_Hanson_County_2012',
#  'SD_Hutchinson_County_2012',
#  'SD_James_River_NRCS_G_2010',
#  'SD_James_River_NRCS_H_2010',
#  'SD_James_River_NRCS_I_2010',
#  'SD_James_River_NRCS_J_2010',
#  'SD_Kingsbury_County_2012',
#  'SD_LincolnCo_2008',
#  'SD_MO_River_Dewberry_B1_2016',
#  'SD_McCook_County_2012',
#  'SD_Miner_County_2012',
#  'SD_MinnehahaCo_2008',
#  'SD_Moody_County_2012',
#  'SD_RileyPass_2012',
#  'SD_Roberts_County_2012',
#  'SD_Sanborn_County_2012',
#  'SD_Southwest_B1_2018',
#  'SD_Southwest_B2_2018',
#  'SD_Southwest_B3_2018',
#  'SD_Spink_County_2012',
#  'SD_Turner_County_2012',
#  'SD_Union_County_2012',
#  'SD_Yankton_County_2012',
#  'TN_Memphis_2011',
#  'TN_Nashville_2011',
#  'TN_OSMRE-GPSC_2011',
#  'TN_ShelbyCo_2012',
#  'TN_WestTN_B1_2019',
#  'TN_WestTN_B2_2019',
#  'TX_Aransas_Refugio_2006',
#  'TX_Bell-Burnet-McLennan_2011',
#  'TX_Brazoria_2006',
#  'TX_Chambers_2006',
#  'TX_Coastal_B1_2018',
#  'TX_Coastal_B2_Z14_2018',
#  'TX_Coastal_B2_Z15_2018',
#  'TX_Coastal_B3_2018',
#  'TX_ColemanCo_2006',
#  'TX_DesertMountains_B1_2018',
#  'TX_DesertMountains_B2_2018',
#  'TX_FayetteCo_2008',
#  'TX_Galveston_2006',
#  'TX_HaysCo_2008',
#  'TX_Hurricane_B4_2018',
#  'TX_Hurricane_B5B_2018',
#  'TX_Hurricane_B5_2018',
#  'TX_Jackson_2006',
#  'TX_Jefferson_2006',
#  'TX_KimbleCo_2006',
#  'TX_LCRA_Thalweg_2006',
#  'TX_Lower_SanBernard_B3_2017',
#  'TX_Mason_2007',
#  'TX_Matagorda_2006',
#  'TX_MenardCo_2006',
#  'TX_MillsCo_2006',
#  'TX_Orange_2006',
#  'TX_Pecos_Dallas_B1_2018',
#  'TX_Pecos_Dallas_B2a_2018',
#  'TX_Pecos_Dallas_B2b_2018',
#  'TX_Pecos_Dallas_B3_2018',
#  'TX_San_Patricio_2006',
#  'TX_Victoria_2006',
#  'TX_WestTexas_B1_2018',
#  'TX_WestTexas_B2_2018',
#  'TX_WestTexas_B5_2018',
#  'TX_WestTexas_B6_2018',
#  'TX_WestTexas_B7_2018',
#  'TX_WestTexas_B8_2018',
#  'TX_WestTexas_B9_2018',
#  'TX_WestTexas_TL_2018',
#  'USGS_LPC_AK_Anchorage_2015_LAS_2017',
#  'USGS_LPC_AK_FairbanksNSB_QL1_2017_LAS_2018',
#  'USGS_LPC_AK_FairbanksNSB_QL2_2017_LAS_2018',
#  'USGS_LPC_AK_POW_P2_2018_LAS_2019',
#  'USGS_LPC_AK_POW_P2_TL_2018_LAS_2019',
#  'USGS_LPC_AK_PrinceofWalesIsland_2017_LAS_2019',
#  'USGS_LPC_AL_25Co_B1_2017',
#  'USGS_LPC_AL_25Co_B3_2017',
#  'USGS_LPC_AL_25Co_B4_2017',
#  'USGS_LPC_AL_25Co_B5_2017',
#  'USGS_LPC_AL_25Co_B6_2017',
#  'USGS_LPC_AL_25Co_B7_2017',
#  'USGS_LPC_AL_25Co_B8_2017',
#  'USGS_LPC_AL_3County_2015_LAS_2017',
#  'USGS_LPC_AL_ADECA_B1_2016_LAS_2019',
#  'USGS_LPC_AL_ADECA_B2_2016_LAS_2019',
#  'USGS_LPC_AL_AGIO_B1_2016_LAS_2018',
#  'USGS_LPC_AL_AGIO_B1_2016_LAS_2019',
#  'USGS_LPC_AL_AGIO_B2_2016_LAS_2018',
#  'USGS_LPC_AL_AGIO_B2_2016_LAS_2019',
#  'USGS_LPC_AL_Autauga_2010_LAS_2016',
#  'USGS_LPC_AL_Clay_CleburneCo_2013_LAS_2016',
#  'USGS_LPC_AL_Coffee_Dale_GenevaCo_2011_LAS_2016',
#  'USGS_LPC_AL_EscambiaCo_2013_LAS_2016',
#  'USGS_LPC_AL_JeffersonCo_2013_LAS_2015',
#  'USGS_LPC_AL_LawrenceCo_2012_LAS_2018',
#  'USGS_LPC_AL_MobileCo_2014_LAS_2016',
#  'USGS_LPC_AL_MorganCo_2012_LAS_2018',
#  'USGS_LPC_AL_ThreeCo_2012_LAS_2015',
#  'USGS_LPC_AR_Benton_Co_2015_LAS_2017',
#  'USGS_LPC_AR_LAnguillee_2011_LAS_2016',
#  'USGS_LPC_AR_LakeConwayPointRE_2014_LAS_2016',
#  'USGS_LPC_AR_NRCS_A1_2016_LAS_2017',
#  'USGS_LPC_AR_NRCS_A2_2016_LAS_2017',
#  'USGS_LPC_AR_NRCS_A3_2016_LAS_2017',
#  'USGS_LPC_AR_NRCS_A4_2016_LAS_2017',
#  'USGS_LPC_AR_NRCS_A5_2016_LAS_2017',
#  'USGS_LPC_AR_NRCS_Cache_2011_LAS_2016',
#  'USGS_LPC_AR_North_Corridor_B1_2017_LAS_2018',
#  'USGS_LPC_AR_North_Corridor_B2_2017_LAS_2018',
#  'USGS_LPC_AR_North_Corridor_B3_2017_LAS_2018',
#  'USGS_LPC_AR_Ouachita_2016_LAS_2018',
#  'USGS_LPC_AR_Ouachita_B1_2016_LAS_2018',
#  'USGS_LPC_AR_Ouachita_B2_2016_LAS_2018',
#  'USGS_LPC_AR_Ouachita_B3_2016_LAS_2018',
#  'USGS_LPC_AR_Ouachita_B5_2016_LAS_2018',
#  'USGS_LPC_AR_Ouachita_B6_2016_LAS_2018',
#  'USGS_LPC_AR_Ouachita_B7_2016_LAS_2018',
#  'USGS_LPC_AR_R6_JeffersonCO_2015_LAS_2016',
#  'USGS_LPC_AR_R6_LowerBlackwaterWS_2015_LAS_2016',
#  'USGS_LPC_AR_R6_WashingtonCO_2015_LAS_2016',
#  'USGS_LPC_AR_UpperSaline_2014_LAS_2015',
#  'USGS_LPC_AZ_BrawleyRillito_FEMA_2018',
#  'USGS_LPC_AZ_BrawleyRillito_NRCS_2018',
#  'USGS_LPC_AZ_CORiverBasin_L1_2014_LAS_2017',
#  'USGS_LPC_AZ_ColoradoRiverLot2_2014_LAS_2015',
#  'USGS_LPC_AZ_Fredonia_QL1_2016_LAS_2018',
#  'USGS_LPC_AZ_LowerColoradoRiver_2015_LAS_2016',
#  'USGS_LPC_AZ_Safford_QL2_2016_LAS_2018',
#  'USGS_LPC_AZ_VerdeKaibab_B1_2018_LAS_2019',
#  'USGS_LPC_AZ_VerdeKaibab_B1_TL_2018_LAS_2019',
#  'USGS_LPC_AZ_VerdeKaibab_B2_2018_LAS_2019',
#  'USGS_LPC_AZ_VerdeKaibab_B2_TL_2018_LAS_2019',
#  'USGS_LPC_AZ_WalnutGulch_2015_LAS_2017',
#  'USGS_LPC_CA_Central_Valley_2017_LAS_2019',
#  'USGS_LPC_CA_E_SanDiegoCo_2016_LAS_2017',
#  'USGS_LPC_CA_FEMA_R9_Alpine_2017_LAS_2018',
#  'USGS_LPC_CA_FEMA_R9_Cow_Creek_2017_LAS_2018',
#  'USGS_LPC_CA_FEMA_R9_Keefer_2017_LAS_2018',
#  'USGS_LPC_CA_FEMA_R9_Mendocino_HF_2017_LAS_2018',
#  'USGS_LPC_CA_FEMA_R9_Russian_2017_LAS_2018',
#  'USGS_LPC_CA_FEMA_R9_Upper_Pit_2017_LAS_2019',
#  'USGS_LPC_CA_LakeCounty_2015_LAS_2017',
#  'USGS_LPC_CA_LongValleyCaldera_2017_LAS_2018',
#  'USGS_LPC_CA_LosAngeles_2016_LAS_2018',
#  'USGS_LPC_CA_NoCAL_Wildfires_B1_2018',
#  'USGS_LPC_CA_NoCAL_Wildfires_B2_2018',
#  'USGS_LPC_CA_NoCAL_Wildfires_B3_2018',
#  'USGS_LPC_CA_NoCAL_Wildfires_B4_2018',
#  'USGS_LPC_CA_NoCAL_Wildfires_B5a_2018',
#  'USGS_LPC_CA_NoCAL_Wildfires_B5b_2018',
#  'USGS_LPC_CA_NoCAL_Wildfires_PlumasNF_B1_2018',
#  'USGS_LPC_CA_NoCAL_Wildfires_PlumasNF_B2_2018',
#  'USGS_LPC_CA_NoCal_Wildfires_B5b_QL1_2018',
#  'USGS_LPC_CA_NoCal_Wildfires_CampFire_2018',
#  'USGS_LPC_CA_NoCal_Wildfires_GMEG_2018',
#  'USGS_LPC_CA_Riverside_B1_2019',
#  'USGS_LPC_CA_Riverside_B2_2019',
#  'USGS_LPC_CA_SanBernardinoCo_AreaA_2013_LAS_2018',
#  'USGS_LPC_CA_SanBernardinoCo_AreaB_2013_LAS_2018',
#  'USGS_LPC_CA_SanDiegoQL1_2014_LAS_2016',
#  'USGS_LPC_CA_SanDiego_2015_C17_1',
#  'USGS_LPC_CA_SoCAL_Wildfires_TL_2018_LAS_2019',
#  'USGS_LPC_CA_SoCal_Wildfires_B1_2018_LAS_2019',
#  'USGS_LPC_CA_SoCal_Wildfires_B2_2018_LAS_2019',
#  'USGS_LPC_CA_SoCal_Wildfires_B3_2018_LAS_2019',
#  'USGS_LPC_CA_SoCal_Wildfires_B4_2018_LAS_2019',
#  'USGS_LPC_CA_Sonoma_2013_LAS_2017',
#  'USGS_LPC_CA_Sonoma_A2_2013_LAS_2017',
#  'USGS_LPC_CA_Sonoma_A3_2013_LAS_2017',
#  'USGS_LPC_CA_Sonoma_A4_2013_LAS_2017',
#  'USGS_LPC_CA_WestCoastElNinoUTM10_2016_LAS_2017',
#  'USGS_LPC_CA_WestCoastElNinoUTM11_2016_LAS_2017',
#  'USGS_LPC_CO_Central_Western_2016_LAS_2018',
#  'USGS_LPC_CO_MesaCo_QL1_2016_LAS_2017',
#  'USGS_LPC_CO_MesaCo_QL2_2015_LAS_2017',
#  'USGS_LPC_CO_MesaCo_QL2_UTM13_2015_LAS_2017',
#  'USGS_LPC_CO_SanJuan_NF_2017_LAS_2018',
#  'USGS_LPC_CO_SoPlatteRiver_Lot1_2013_LAS_2015',
#  'USGS_LPC_CO_SoPlatteRiver_Lot2a_2013_LAS_2015',
#  'USGS_LPC_CO_SoPlatteRiver_Lot5_2013_LAS_2015',
#  'USGS_LPC_CO_SoPlatte_Lot3_2013_LAS_2015',
#  'USGS_LPC_CT_River_Lot6_Winnipesaulee_2015_LAS_2017',
#  'USGS_LPC_CT_Sandy_2014_LAS_2015',
#  'USGS_LPC_CT_Statewide_B8_2016',
#  'USGS_LPC_DE_DelawareValleyHD_5A_2015_LAS_2017',
#  'USGS_LPC_DE_DelawareValley_HD_2015_LAS_2017',
#  'USGS_LPC_DE_Snds_2013_LAS_2015',
#  'USGS_LPC_FL_LeonCo_2018_LAS_2019',
#  'USGS_LPC_FL_Lower_Choctawhatchee_2017_LAS_2019',
#  'USGS_LPC_FL_Lower_Choctawhatchee_TL_2017_LAS_2019',
#  'USGS_LPC_FL_MartinCo_2015_LAS_2017',
#  'USGS_LPC_FL_PalmBeachCo_2016_LAS_2019',
#  'USGS_LPC_FL_Panhandle_B1_2018_LAS_2019',
#  'USGS_LPC_FL_Panhandle_B2_2018_LAS_2019',
#  'USGS_LPC_FL_Panhandle_B3_2018_LAS_2019',
#  'USGS_LPC_FL_PeaceRiver_2014_LAS_2018',
#  'USGS_LPC_FL_Southeast_B1_2018_LAS_2019',
#  'USGS_LPC_FL_Southeast_B2_2018_LAS_2019',
#  'USGS_LPC_FL_Southeast_TL_2018_LAS_2019',
#  'USGS_LPC_FL_Southwest_A_2018_LAS_2019',
#  'USGS_LPC_FL_Southwest_B_2018_LAS_2019',
#  'USGS_LPC_FL_Southwest_B_TL_2018_LAS_2019',
#  'USGS_LPC_FL_SuwanneeRiver_2017_LAS_2018',
#  'USGS_LPC_FL_Suwannee_NCentral_2014_LAS_2016',
#  'USGS_LPC_FL_Upper_Saint_Johns_2017_LAS_2019',
#  'USGS_LPC_GA_Georgia_A1_2016_LAS_2018',
#  'USGS_LPC_GA_Georgia_A2_2016_LAS_2018',
#  'USGS_LPC_GA_Georgia_A3_2016_LAS_2018',
#  'USGS_LPC_HI_Oahu_2012_LAS_2015',
#  'USGS_LPC_ID_Clearwater_d1_2010_LAS_2015',
#  'USGS_LPC_ID_EmeraldCreek_2004_LAS_2016',
#  'USGS_LPC_ID_FEMAHQ_2018_LAS_2019',
#  'USGS_LPC_ID_JackWaite_2007_LAS_2016',
#  'USGS_LPC_ID_MoscowMountain_2003_LAS_2015',
#  'USGS_LPC_ID_NezPerce_QL1_2016_LAS_2019',
#  'USGS_LPC_ID_NezPerce_QL2_2016_LAS_2019',
#  'USGS_LPC_ID_Nez_Perce_QL1_TL_2016_LAS_2019',
#  'USGS_LPC_ID_Nez_Perce_QL2_TL_2016_LAS_2019',
#  'USGS_LPC_ID_Payette_NF_QL2_2017_LAS_2018',
#  'USGS_LPC_ID_SaintJoe_2003_LAS_2015',
#  'USGS_LPC_ID_SlateLolo_2006_LAS_2015',
#  'USGS_LPC_IL_12County_KaneCo_2008_LAS_2015',
#  'USGS_LPC_IL_12_County_CarollCo_2009_LAS_2015',
#  'USGS_LPC_IL_12_County_ChampaignCo_2008_LAS_2016',
#  'USGS_LPC_IL_12_County_GrundyCo_2008_LAS_2016',
#  'USGS_LPC_IL_12_County_HenryCo_2009_LAS_2016',
#  'USGS_LPC_IL_12_County_OgleCo_2008_LAS_2015',
#  'USGS_LPC_IL_12_County_Stephenson_Co_2009_LAS_2016',
#  'USGS_LPC_IL_4County_Cook_2017_LAS_2019',
#  'USGS_LPC_IL_4County_Kane_2018_LAS_2019',
#  'USGS_LPC_IL_4County_Lake_2016_LAS_2019',
#  'USGS_LPC_IL_4County_McHenry_2018_LAS_2019',
#  'USGS_LPC_IL_5County_KankakeeCo_2014_LAS_2016',
#  'USGS_LPC_IL_5County_WillCo_2014_LAS_2016',
#  'USGS_LPC_IL_5county_MarionCo_2015_LAS_2016',
#  'USGS_LPC_IL_BondCo_2015_LAS_2016',
#  'USGS_LPC_IL_Boone_2018',
#  'USGS_LPC_IL_BureauCo_2015_LAS_2017',
#  'USGS_LPC_IL_ChristianCo_2014_LAS_2016',
#  'USGS_LPC_IL_ClintonCo_2015_LAS_2016',
#  'USGS_LPC_IL_DOT_District5_DewittCo_2012_LAS_2017',
#  'USGS_LPC_IL_DOT_District5_EdgarCo_2012_LAS_2017',
#  'USGS_LPC_IL_DOT_District5_McleanCo_2012_LAS_2017',
#  'USGS_LPC_IL_DOT_District5_PiattCo_2012_LAS_2017',
#  'USGS_LPC_IL_DOT_District5_VermilionCo_2012_LAS_2017',
#  'USGS_LPC_IL_DOT_District_7_LiDAR_LAS_2017',
#  'USGS_LPC_IL_District4_Fulton_2014_LAS_2018',
#  'USGS_LPC_IL_District4_Henderson_2014_LAS_2016',
#  'USGS_LPC_IL_District4_Knox_2014_LAS_2017',
#  'USGS_LPC_IL_District4_Marshal_2014_LAS_2016',
#  'USGS_LPC_IL_District4_McDonough_2014_LAS_2018',
#  'USGS_LPC_IL_District4_Mercer_2014_LAS_2016',
#  'USGS_LPC_IL_District4_Peoria_2014_LAS_2016',
#  'USGS_LPC_IL_District4_Putnam_2014_LAS_2017',
#  'USGS_LPC_IL_District4_Stark_2014_LAS_2018',
#  'USGS_LPC_IL_District4_Tazewell_2014_LAS_2016',
#  'USGS_LPC_IL_District4_Warren_2014_LAS_2018',
#  'USGS_LPC_IL_District4_Woodford_2014_LAS_2016',
#  'USGS_LPC_IL_District5_DouglasCo_2012_LAS_2018',
#  'USGS_LPC_IL_District7_Clark_2014_LAS_2017',
#  'USGS_LPC_IL_District7_Crawford_2014_LAS_2017',
#  'USGS_LPC_IL_District7_Cumberland_2014_LAS_2017',
#  'USGS_LPC_IL_District7_Edwards_2014_LAS_2017',
#  'USGS_LPC_IL_District7_Effingham_2014_LAS_2017',
#  'USGS_LPC_IL_District7_Fayette_2014_LAS_2017',
#  'USGS_LPC_IL_District7_Macon_2014_LAS_2017',
#  'USGS_LPC_IL_District7_Moultrie_2014_LAS_2018',
#  'USGS_LPC_IL_District7_Richland_2014_LAS_2017',
#  'USGS_LPC_IL_District7_Shelby_2014_LAS_2017',
#  'USGS_LPC_IL_District7_Wabash_2014_LAS_2017',
#  'USGS_LPC_IL_District7_Wayne_2014_LAS_2018',
#  'USGS_LPC_IL_FordIroqouisLivingston_2015_LAS_2017',
#  'USGS_LPC_IL_FordIroquoisLivingston_L1_2014_LAS_2017',
#  'USGS_LPC_IL_FordIroquoisLivingston_L3_2014_LAS_2017',
#  'USGS_LPC_IL_FordIroquoisLivingston_L4_2014_LAS_2017',
#  'USGS_LPC_IL_FranklinCo_2014_LAS_2018',
#  'USGS_LPC_IL_GrnMacMont_2017_LAS_2018',
#  'USGS_LPC_IL_HancockCo_2017_LAS_2018',
#  'USGS_LPC_IL_Hardin_2014_LAS_2017',
#  'USGS_LPC_IL_JacksonCo_2015_LAS_2018',
#  'USGS_LPC_IL_Jasper_2014_LAS_2017',
#  'USGS_LPC_IL_JeffersonCo_2015_LAS_2016',
#  'USGS_LPC_IL_JoDaviessCo_2008_LAS_2015',
#  'USGS_LPC_IL_LaSalle_B1_2017_LAS_2019',
#  'USGS_LPC_IL_LaSalle_B2_2017_LAS_2019',
#  'USGS_LPC_IL_LeeCo_2008_LAS_2015',
#  'USGS_LPC_IL_LoganCo_2013_LAS_2015',
#  'USGS_LPC_IL_MadisonCo_2014_LAS_2016',
#  'USGS_LPC_IL_PerryCo_2015_LAS_2019',
#  'USGS_LPC_IL_Pike_ScottCo_2015_LAS_2017',
#  'USGS_LPC_IL_Pope_2014_LAS_2017',
#  'USGS_LPC_IL_Twelve_Counties_McHenry_LAS_2016',
#  'USGS_LPC_IL_WashingtonCo_2015_LAS_2016',
#  'USGS_LPC_IL_WestCentral_2017_LAS_2019',
#  'USGS_LPC_IL_WhitesideCO_2009_LAS_2015',
#  'USGS_LPC_IN_Central_Hamilton_2017_LAS_2019',
#  'USGS_LPC_IN_Central_MarionCo_2016_LAS_2018',
#  'USGS_LPC_IN_Central_Wayne_2016_LAS_2019',
#  'USGS_LPC_IN_ET_B5_Allen_2012__LAS_2016',
#  'USGS_LPC_IN_ET_B5_Dekalb_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B5_LaGrange_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B5_Noble_2012__LAS_2016',
#  'USGS_LPC_IN_ET_B5_Steuben_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B5_Whitley_2012__LAS_2016',
#  'USGS_LPC_IN_ET_B6_Adams_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B6_Blackford_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B6_Delaware_2012_LAS_2017',
#  'USGS_LPC_IN_ET_B6_Grant_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B6_Hamilton_2012_LAS_2017',
#  'USGS_LPC_IN_ET_B6_Huntington_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B6_Jay_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B6_Madison_2012_LAS_2017',
#  'USGS_LPC_IN_ET_B6_Randolph_2012_LAS_2017',
#  'USGS_LPC_IN_ET_B6_Wells_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B7_Decatur_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B7_Fayette_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B7_Franklin_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B7_Hancock_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B7_Henry_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B7_Rush_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B7_Shelby_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B7_Union_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B7_Wayne_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B8_Clark_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B8_Dearborn_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B8_Floyd_2011_LAS_2016',
#  'USGS_LPC_IN_ET_B8_Jefferson_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B8_Jennings_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B8_Ohio_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B8_RipleyCo_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B8_Scott_2012_LAS_2016',
#  'USGS_LPC_IN_ET_B8_Switzerland_2012_LAS_2016',
#  'USGS_LPC_IN_HendricksCo_2011_LAS_2015',
#  'USGS_LPC_IN_Hendricks_2011_LAS_2016',
#  'USGS_LPC_IN_JohnsonCo_2011_LAS_2015',
#  'USGS_LPC_IN_JohnsonCo_2011_LAS_2016',
#  'USGS_LPC_IN_Johnson_2011_LAS_2016',
#  'USGS_LPC_IN_MarionCo_2011_LAS_2016',
#  'USGS_LPC_IN_Marion_2011_LAS_2016',
#  'USGS_LPC_IN_Monroe_2011_LAS_2016',
#  'USGS_LPC_IN_Morgan_2011_LAS_2016',
#  'USGS_LPC_IN_WT_B10_Benton_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B10_Fountain_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B10_Montgomery_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B10_Tippecanoe_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B10_Warren_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B10_White_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B11_Clay_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B11_Greene_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B11_Owen_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B11_Parke_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B11_Putnam_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B11_Sullivan_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B11_Vermillion_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B11_Vigo_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B12_Daviess_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B12_Dubois_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B12_Gibson_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B12_Knox_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B12_Martin_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B12_Perry_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B12_Pike_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B12_Posey_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B12_Spencer_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B12_Vanderburgh_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B12_Warrick_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B9_Jasper_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B9_Lake_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B9_Laporte_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B9_Newton_2013_LAS_2016',
#  'USGS_LPC_IN_WT_B9_Porter_2013_LAS_2016',
#  'USGS_LPC_Il_12Counties_Rock_IslandCo_LAS_2016',
#  'USGS_LPC_KS_15CoNorth_A1_2015_LAS_2017',
#  'USGS_LPC_KS_15CoNorth_A2_2015_LAS_2017',
#  'USGS_LPC_KS_15CoNorth_A3_2015_LAS_2017',
#  'USGS_LPC_KS_15Co_Cheney_2015_LAS_2017',
#  'USGS_LPC_KS_15Co_South_2015_LAS_2017',
#  'USGS_LPC_KS_Area1_2014_LAS_2015',
#  'USGS_LPC_KS_Area1_Eastern_2011_LAS_2016',
#  'USGS_LPC_KS_Area2_2014_LAS_2015',
#  'USGS_LPC_KS_Area2_B1_2012_LAS_2016',
#  'USGS_LPC_KS_Area2_B2_2012_LAS_2016',
#  'USGS_LPC_KS_Area2_B3_2012_LAS_2016',
#  'USGS_LPC_KS_Area2_B4_2012_LAS_2016',
#  'USGS_LPC_KS_Area2_B5_2012_LAS_2016',
#  'USGS_LPC_KS_Area2_B6_2012_LAS_2016',
#  'USGS_LPC_KS_Lidar_1_B1_2013_LAS_2016',
#  'USGS_LPC_KS_Lidar_1_B2_2013_LAS_2016',
#  'USGS_LPC_KS_Lidar_1_B3_2013_LAS_2016',
#  'USGS_LPC_KS_Lidar_1_B4_2013_LAS_2016',
#  'USGS_LPC_KS_Lidar_1_B5_2013_LAS_2016',
#  'USGS_LPC_KS_Lidar_1_B6_2013_LAS_2016',
#  'USGS_LPC_KS_NF_Nin_Sub_2011_LAS_2016',
#  'USGS_LPC_KS_SCentral_L1_2015_LAS_2017',
#  'USGS_LPC_KS_SCentral_L2_2015_LAS_2017',
#  'USGS_LPC_KS_SCentral_L3_2015_LAS_2017',
#  'USGS_LPC_KS_SCentral_L4_2015_LAS_2017',
#  'USGS_LPC_KS_South_Central_AOI_2_Manhattan_2015_LAS_2017',
#  'USGS_LPC_KS_Statewide_B1_2017_LAS_2018',
#  'USGS_LPC_KY_KYAPED_Area2_2012_LAS_2017',
#  'USGS_LPC_KY_NRCS_Watersheds_2011_LAS_2016',
#  'USGS_LPC_LA_Amite_2018_LAS_2019',
#  'USGS_LPC_LA_Barataria_2013_LAS_2015',
#  'USGS_LPC_LA_Bayou_Nezpique_B1_2018',
#  'USGS_LPC_LA_Bayou_Nezpique_B2_2018',
#  'USGS_LPC_LA_Bayou_Nezpique_B3_2018',
#  'USGS_LPC_LA_Bayou_Nezpique_B6_2018',
#  'USGS_LPC_LA_Chenier_Plain_2017_LAS_2018',
#  'USGS_LPC_LA_SoTerrebonne_GI_2015_LAS_2016',
#  ...]

# %%
df.head()
# Out:
#                          Region  \
# 0           AK_BrooksCamp_2012/
# 1              AK_Coastal_2009/
# 2  AK_Fairbanks-NSBorough_2010/
# 3               AK_Juneau_2012/
# 4                AK_Kenai_2008/
#
#                                            File_path  \
# 0  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 1  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 2  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 3  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 4  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
#
#                                               Bounds  \
# 0  [-17347360, 8065364, -12414, -17321558, 809116...
# 1  [-15730544, 10937407, -19027, -15691854, 10976...
# 2  [-16471700, 9519129, -45314, -16381190, 960963...
# 3  [-15014449, 8012267, -35030, -14943073, 808364...
# 4  [-16906356, 8303726, -166851, -16570284, 86397...
#
#                                                  WKT
# 0  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 1  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 2  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 3  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...
# 4  PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS ...

# %%
#Drop the z min and z max values
for i in df['Bounds']:
    del i[2]
for i in df['Bounds']:
    del i[4]

# %%
df.Bounds.loc[:5]
# Out:
# 0      [-17347360, 8065364, -17321558, 8091166]
# 1    [-15730544, 10937407, -15691854, 10976097]
# 2      [-16471700, 9519129, -16381190, 9609639]
# 3      [-15014449, 8012267, -14943073, 8083643]
# 4      [-16906356, 8303726, -16570284, 8639798]
# 5      [-16782341, 8663224, -16678201, 8767364]
# Name: Bounds, dtype: object

# %% [markdown]
# bounds_list = []
# x = df.Bounds.loc[:5]
# def split_list(a_list):
#     half = len(a_list)//2
#     return a_list[:half],a_list[half:]
#
# for i in df['Bounds']:
#     bounds = []
#     a,b = split_list(i)
#     bounds = tuple([a,b])
#     bounds_list.append(bounds)

# %% [markdown]
# df['Bounds'] =bounds_list

# %%
df.sample(5)
# Out:
#                                           Region  \
# 847  USGS_LPC_IL_District4_Warren_2014_LAS_2018/
# 332                          KY_Eastern_B2_2019/
# 557                        SC_DarlingtonCo_2008/
# 679           USGS_LPC_AL_AGIO_B2_2016_LAS_2019/
# 13                        AK_NorthSlope_B1_2018/
#
#                                              File_path  \
# 847  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 332  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 557  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 679  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 13   https://s3-us-west-2.amazonaws.com/usgs-lidar-...
#
#                                          Bounds
# 847    [-10121233, 4956438, -10053481, 5024190]
# 332      [-9412640, 4438276, -9122740, 4728176]
# 557      [-8937867, 4035407, -8865713, 4107561]
# 679      [-9890337, 3803583, -9727367, 3966553]
# 13   [-15990539, 11105651, -15983447, 11112743]

# %%
#df.to_csv("../data/data.csv",index=False)

# %%
#df.to_json("../data/clean_data.json")

# %%
polygon = []
for b in df.Bounds:
    MINX,MINY,MAXX,MAXY = [b[0],b[1],b[2],b[3]]
    poly = Polygon(((MINX, MINY), (MINX, MAXY), (MAXX, MAXY), (MAXX, MINY), (MINX, MINY)))
    polygon.append(poly)

# %%
df['geometry'] = polygon
df.head()
# Out:
#                          Region  \
# 0           AK_BrooksCamp_2012/
# 1              AK_Coastal_2009/
# 2  AK_Fairbanks-NSBorough_2010/
# 3               AK_Juneau_2012/
# 4                AK_Kenai_2008/
#
#                                            File_path  \
# 0  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 1  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 2  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 3  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 4  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
#
#                                        Bounds  \
# 0    [-17347360, 8065364, -17321558, 8091166]
# 1  [-15730544, 10937407, -15691854, 10976097]
# 2    [-16471700, 9519129, -16381190, 9609639]
# 3    [-15014449, 8012267, -14943073, 8083643]
# 4    [-16906356, 8303726, -16570284, 8639798]
#
#                                             geometry
# 0  POLYGON ((-17347360 8065364, -17347360 8091166...
# 1  POLYGON ((-15730544 10937407, -15730544 109760...
# 2  POLYGON ((-16471700 9519129, -16471700 9609639...
# 3  POLYGON ((-15014449 8012267, -15014449 8083643...
# 4  POLYGON ((-16906356 8303726, -16906356 8639798...

# %%
x,y =

# %%
gdf = geopandas.GeoDataFrame(df)
gdf.head()
# Out:
#                          Region  \
# 0           AK_BrooksCamp_2012/
# 1              AK_Coastal_2009/
# 2  AK_Fairbanks-NSBorough_2010/
# 3               AK_Juneau_2012/
# 4                AK_Kenai_2008/
#
#                                            File_path  \
# 0  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 1  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 2  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 3  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
# 4  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
#
#                                        Bounds  \
# 0    [-17347360, 8065364, -17321558, 8091166]
# 1  [-15730544, 10937407, -15691854, 10976097]
# 2    [-16471700, 9519129, -16381190, 9609639]
# 3    [-15014449, 8012267, -14943073, 8083643]
# 4    [-16906356, 8303726, -16570284, 8639798]
#
#                                             geometry
# 0  POLYGON ((-17347360.000 8065364.000, -17347360...
# 1  POLYGON ((-15730544.000 10937407.000, -1573054...
# 2  POLYGON ((-16471700.000 9519129.000, -16471700...
# 3  POLYGON ((-15014449.000 8012267.000, -15014449...
# 4  POLYGON ((-16906356.000 8303726.000, -16906356...

# %%
gdf['area'] = gdf.area
# Returns a GeoSeries of points for each geometric centroid.
gdf['centroid'] = gdf.centroid
# Returns a GeoSeries of geometries representing the point or smallest rectangular
# polygon (with sides parallel to the coordinate axes) that contains each object.
gdf['envelope'] = gdf.envelope

# %%
gdf = gdf.drop(['File_path','Bounds'],axis=1)
gdf.sample()
# Out:
#                   Region                                           geometry  \
# 1544  VT_RockRiver_2008/  POLYGON ((-8159821.000 5579646.000, -8159821.0...
#
#               area                          centroid  \
# 1544  1.999521e+09  POINT (-8137463.000 5602004.000)
#
#                                                envelope
# 1544  POLYGON ((-8159821.000 5579646.000, -8115105.0...

# %%
gdf.crs = "EPSG:4326"
print(gdf.crs)
# Out:
# EPSG:4326

# %%
gdf.sample()
# Out:
#                            Region  \
# 38  ARRA-CA_CentralCoast-Z4_2010/
#
#                                             File_path  \
# 38  https://s3-us-west-2.amazonaws.com/usgs-lidar-...
#
#                                       Bounds  \
# 38  [-13590521, 4270733, -13426673, 4434581]
#
#                                              geometry          area  \
# 38  POLYGON ((-13590521.000 4270733.000, -13590521...  2.684617e+10
#
#                              centroid  \
# 38  POINT (-13508597.000 4352657.000)
#
#                                              envelope
# 38  POLYGON ((-13590521.000 4270733.000, -13426673...

# %%
m = folium.Map(location=[37.0902,-95.7129], zoom_start=10, tiles='CartoDB positron')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_0532d79a05cd439ea0fbce860a049d23%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0532d79a05cd439ea0fbce860a049d23%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_0532d79a05cd439ea0fbce860a049d23%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_0532d79a05cd439ea0fbce860a049d23%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.0902%2C%20-95.7129%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
gdf['lat'] = gdf.centroid.y
gdf['lon'] = gdf.centroid.x
gdf.head()
# Out:
# /tmp/ipykernel_19979/3024331562.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf['lat'] = gdf.centroid.y
# /tmp/ipykernel_19979/3024331562.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf['lon'] = gdf.centroid.x
#                          Region  \
# 0           AK_BrooksCamp_2012/
# 1              AK_Coastal_2009/
# 2  AK_Fairbanks-NSBorough_2010/
# 3               AK_Juneau_2012/
# 4                AK_Kenai_2008/
#
#                                             geometry          area  \
# 0  POLYGON ((-17347360.000 8065364.000, -17347360...  6.657432e+08
# 1  POLYGON ((-15730544.000 10937407.000, -1573054...  1.496916e+09
# 2  POLYGON ((-16471700.000 9519129.000, -16471700...  8.192060e+09
# 3  POLYGON ((-15014449.000 8012267.000, -15014449...  5.094533e+09
# 4  POLYGON ((-16906356.000 8303726.000, -16906356...  1.129444e+11
#
#                              centroid  \
# 0   POINT (-17334459.000 8078265.000)
# 1  POINT (-15711199.000 10956752.000)
# 2   POINT (-16426445.000 9564384.000)
# 3   POINT (-14978761.000 8047955.000)
# 4   POINT (-16738320.000 8471762.000)
#
#                                             envelope         lat         lon
# 0  POLYGON ((-17347360.000 8065364.000, -17321558...   8078265.0 -17334459.0
# 1  POLYGON ((-15730544.000 10937407.000, -1569185...  10956752.0 -15711199.0
# 2  POLYGON ((-16471700.000 9519129.000, -16381190...   9564384.0 -16426445.0
# 3  POLYGON ((-15014449.000 8012267.000, -14943073...   8047955.0 -14978761.0
# 4  POLYGON ((-16906356.000 8303726.000, -16570284...   8471762.0 -16738320.0

# %%
# Estimate centroids of the country
# --------------------
cent_x =gdf['geometry'].centroid.x.mean()
cent_y =gdf['geometry'].centroid.y.mean()

# Create a map object using Folium
# --------------------
map_usa = folium.Map(location=[cent_y, cent_x], zoom_start=7, tiles='OpenStreetMap')  

# Create the choropleth map
# --------------------
choro = folium.Choropleth(geo_data=gdf,
                         name='choropleth',     
                          data=usa_g,
                          columns=['NAME_2', 'area'], 
#                           key_on='feature.NAME_2', 
                          fill_color='YlOrRd',
                          fill_opacity=0.6, 
                          line_opacity=0.8,
                          legend_name= "Area size across USA's subregion"
                          ).add_to(map_usa) 

# add labels to map
choro.geojson.add_child(folium.features.GeoJsonTooltip(fields=['NAME_2', 'area'],
                                                       aliases=['County', 'Mass'], 
                                                       labels = False))
folium.LayerControl().add_to(map_usa)


map_usa
# Out:
# /tmp/ipykernel_19979/3195566992.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   cent_x =gdf['geometry'].centroid.x.mean()
# /tmp/ipykernel_19979/3195566992.py:4: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   cent_y =gdf['geometry'].centroid.y.mean()
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_19979/3195566992.py in <module>
#      12 choro = folium.Choropleth(geo_data=gdf,
#      13                          name='choropleth',
# ---> 14                           data=usa_g,
#      15                           columns=['NAME_2', 'area'],
#      16 #                           key_on='feature.NAME_2',
#
# NameError: name 'usa_g' is not defined
